# %% [markdown]
# <a href="https://colab.research.google.com/github/habibaelbasiouny-collab/Basics-python/blob/main/Copy_of_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('I Love Pyton')
print()
print('print(I love python)')
# Out:
# I Love Pyton
#
# print(I love python)

# %%
# to make variables
user_name = 'nour'
age = 22
print('user_name is:',user_name,' age is:',age)
# Out:
# user_name is: nour  age is: 22

# %%
#input --> allow you to take input the user
name = input('whats your name ?\n')
print('welcome', name)
age = input('whats your age ?\n')
print('my age is ',age)
# Out:
# whats your name ?
# habiba
# welcome habiba
# whats your age ?
# 25
# my age is  25

# %%
# tom make inputs
print('welcome to our app')
nick_name = input('whats your nick_name ? \n')
channel = input ('whats your channel about ? \n')
print('You could name your channel' , channel ,'with', nick_name)
# Out:
# welcome to our app
# whats your nick_name ?
# biba
# whats your channel about ?
# cooking
# You could name your channel cooking with biba

# %%
#to convert from type to type
c = 123
d = str(c)
print (type(d))
print (d)
# Out:
# <class 'str'>
# 123

# %%
age = int(input('enter your age\n'))
print(age + 5)
# Out:
# enter your age
# 45
# 50

# %%
lenght = int(input ('enter the length of the room \n'))
width =int (input ( 'enter the width of thr room \n'))
prices =  int (input ('how mush of 1 meter ?\n'))
print ('the total ares is \n', lenght * width)
print ('you will gave the guy \n',prices * (lenght*width) )
# Out:
# enter the length of the room
# 4
# enter the width of thr room
# 5
# how mush of 1 meter ?
# 12
# the total ares is
#  20
# you will gave the guy
#  240

# %%
# 1000 cup and 105 tables
print (1000 / 105 )
print (1000 // 105)
print (1000 % 105)
# Out:
# 9.523809523809524
# 9
# 55

# %%
min = int (input('enter total minutes'))
print ('the session is ',min//60 ,'hours and',min%60, 'minutes')
# Out:
# enter total minutes200
# the session is  3 hours and 20 minutes

# %%
text = 'hello ahmed'
print(len(text))
# Out:
# 11

# %%
# enter the duration in seconds --> 150
sec = int (input('enter total sec'))
print ('the duration is :',sec // 3600,'hours',sec//60,'min' ,sec %60,'sec')
# Out:
# enter total sec150
# the duration is : 0 hours 2 min 30 sec

# %%
text = 'hello ahmed'
print (len(text) )
print (text[10])
print (text[0])
print (text[-1])
# Out:
# 11
# d
# h
# d

# %%
# text functions
text = ' hELLO pyTHON HELlo AhMeD'
print (text.capitalize())
print (text.upper())
print (text.lower())
print (text.title())
# Out:
#  hello python hello ahmed
#  HELLO PYTHON HELLO AHMED
#  hello python hello ahmed
#  Hello Python Hello Ahmed

# %%
# one variable --> contains one value (int-str-float-bool)
# one variable --> contains many values (list-tuple-set-dict)

# %%
# list[]
fruits = ['cherry' , 'banana' , 'apple']
print(type(fruits))

# acsess element
print (fruits[1])

# MOdify element
fruits[1]= 'blueberry'
print (fruits)

# Add element
fruits.append('orange')
print(fruits)

# Remove element
fruits.remove('cherry')
print(fruits)
# Out:
# <class 'list'>
# banana
# ['cherry', 'blueberry', 'apple']
# ['cherry', 'blueberry', 'apple', 'orange']
# ['blueberry', 'apple', 'orange']
